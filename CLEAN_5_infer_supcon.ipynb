# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/CLEAN/app')
current_path = os.getcwd()
os.listdir(current_path)
# Out:
# ['CLEAN_infer_fasta.py',
#  'DEMO.ipynb',
#  'build.py',
#  'data',
#  'gmm.py',
#  'inference.py',
#  'requirements.txt',
#  'results',
#  'src',
#  'train-supconH.py',
#  'train-triplet.py',
#  'esm',
#  'new-train-triplet.py',
#  'new-train-supconH.py']

# %%
# !pip install fair-esm  # latest release
# Out:
# Collecting fair-esm
#   Downloading fair_esm-2.0.0-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: fair-esm
# Successfully installed fair-esm-2.0.0

# %% [markdown]
# RUN ONLY ONCE

# %%
# from src.CLEAN.utils import csv_to_fasta, retrive_esm1b_embedding
# csv_to_fasta("data/new.csv", "data/new.fasta")
# retrive_esm1b_embedding("new")

# %%
from src.CLEAN.newinfer import infer_pvalue
train_data = "combined_columns"
test_data = "new"
infer_pvalue(train_data, test_data, p_value=1e-1, nk_random=1, report_metrics=True, pretrained=False, model_name='combined_columns_supcon')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-11f7467d6234> in <cell line: 4>()
#       2 train_data = "combined_columns"
#       3 test_data = "new"
# ----> 4 infer_pvalue(train_data, test_data, p_value=1e-1, nk_random=1, report_metrics=True, pretrained=False, model_name='combined_columns_supcon')
#
# /content/drive/MyDrive/CLEAN/app/src/CLEAN/newinfer.py in infer_pvalue(train_data, test_data, p_value, nk_random, report_metrics, pretrained, model_name)
#      43         emb_train = torch.load('./data/pretrained/100.pt', map_location=device)
#      44     else:
# ---> 45         emb_train = model(esm_embedding(ec_id_dict_train, device, dtype))
#      46
#      47     emb_test = model_embedding_test(id_ec_test, model, device, dtype)
#
# /content/drive/MyDrive/CLEAN/app/src/CLEAN/utils.py in esm_embedding(ec_id_dict, device, dtype)
#      75     for ec in list(ec_id_dict.keys()):
#      76         ids_for_query = list(ec_id_dict[ec])
# ---> 77         esm_to_cat = [load_esm(id) for id in ids_for_query]
#      78         esm_emb = esm_emb + esm_to_cat
#      79     return torch.cat(esm_emb).to(device=device, dtype=dtype)
#
# /content/drive/MyDrive/CLEAN/app/src/CLEAN/utils.py in <listcomp>(.0)
#      75     for ec in list(ec_id_dict.keys()):
#      76         ids_for_query = list(ec_id_dict[ec])
# ---> 77         esm_to_cat = [load_esm(id) for id in ids_for_query]
#      78         esm_emb = esm_emb + esm_to_cat
#      79     return torch.cat(esm_emb).to(device=device, dtype=dtype)
#
# /content/drive/MyDrive/CLEAN/app/src/CLEAN/utils.py in load_esm(lookup)
#      62
#      63 def load_esm(lookup):
# ---> 64     esm = format_esm(torch.load('./data/esm_data/' + lookup + '.pt'))
#      65     return esm.unsqueeze(0)
#      66
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     985
#     986     with _open_file_like(f, 'rb') as opened_file:
# --> 987         if _is_zipfile(opened_file):
#     988             # The zipfile reader is going to advance the current file position.
#     989             # If we want to actually tail call to torch.jit.load, we need to
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _is_zipfile(f)
#     119     start = f.tell()
#     120
# --> 121     byte = f.read(1)
#     122     while byte != b"":
#     123         read_bytes.append(byte)
#
# KeyboardInterrupt:

# %%
from src.CLEAN.newinfer import infer_maxsep
train_data = "combined_columns"
test_data = "new"
infer_maxsep(train_data, test_data, report_metrics=True, pretrained=False, model_name="combined_columns_supcon")
