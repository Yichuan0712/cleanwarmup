# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/CLEAN/app')
current_path = os.getcwd()
os.listdir(current_path)
# Out:
# ['CLEAN_infer_fasta.py',
#  'DEMO.ipynb',
#  'build.py',
#  'data',
#  'gmm.py',
#  'inference.py',
#  'requirements.txt',
#  'results',
#  'src',
#  'train-supconH.py',
#  'train-triplet.py',
#  'esm',
#  'new-train-triplet.py',
#  'new-train-supconH.py']

# %%
# !pip install fair-esm  # latest release
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 3.7 MB/s eta 0:00:00
# ...

# %%
model_name = 'combined_columns_triplet'
epoch = '10'
with open('./data/model/' + model_name + '_' + str(epoch) + '.pth', 'w') as file:
    pass
# !python new-train-triplet.py --training_data combined_columns --model_name combined_columns_triplet --epoch 10
# Out:
# ==> device used: cuda:0 | dtype used:  torch.float32
# ==> args: Namespace(learning_rate=0.0005, epoch=10, model_name='combined_columns_triplet', training_data='combined_columns', hidden_dim=512, out_dim=128, adaptive_rate=100, verbose=False)
# The number of unique EC numbers:  9
# ---------------------------------------------------------------------------
# | end of epoch   1 | time:  5.86s | training loss 0.9207
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch   2 | time:  7.54s | training loss 0.9415
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch   3 | time:  6.86s | training loss 0.8611
# ---------------------------------------------------------------------------
# ...

# %%
model_name = 'combined_columns_supcon'
epoch = '10'
with open('./data/model/' + model_name + '_' + str(epoch) + '.pth', 'w') as file:
    pass
# !python new-train-supconH.py --training_data combined_columns --model_name combined_columns_supcon --epoch 10 --n_pos 9 --n_neg 30 -T 0.1
# Out:
# ==> device used: cuda:0 | dtype used:  torch.float32
# ==> args: Namespace(learning_rate=0.0005, epoch=10, model_name='combined_columns_supcon', training_data='combined_columns', temp=0.1, n_pos=9, n_neg=30, hidden_dim=512, out_dim=256, adaptive_rate=60, verbose=False)
# The number of unique EC numbers:  9
# ---------------------------------------------------------------------------
# | end of epoch   1 | time: 46.62s | training loss 3.7171
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch   2 | time: 37.58s | training loss 3.6554
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch   3 | time: 38.86s | training loss 3.6744
# ---------------------------------------------------------------------------
# ...
