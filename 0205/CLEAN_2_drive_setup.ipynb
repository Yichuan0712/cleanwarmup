# %% [markdown]
# This ipynb set up the environment to run clean using the data from MUTarget
#
# ONLY RUN THIS ONCE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive')
current_path = os.getcwd()
os.listdir(current_path)
# Out:
# ['Colab Notebooks', 'MUTarget_data']

# %%
# !git clone https://github.com/tttianhao/CLEAN.git
# Out:
# Cloning into 'CLEAN'...
# remote: Enumerating objects: 954, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 954 (delta 96), reused 87 (delta 82), pack-reused 826
# Receiving objects: 100% (954/954), 449.22 MiB | 11.42 MiB/s, done.
# Resolving deltas: 100% (524/524), done.
# Updating files: 100% (39/39), done.

# %%
os.chdir('CLEAN/app')
current_path = os.getcwd()
os.listdir(current_path)
# Out:
# "\n['CLEAN_infer_fasta.py',\n 'DEMO.ipynb',\n 'build.py',\n 'data',\n 'gmm.py',\n 'inference.py',\n 'requirements.txt',\n 'results',\n 'src',\n 'train-supconH.py',\n 'train-triplet.py']\n"

# %%
# !pip install fair-esm  # latest release
# !git clone https://github.com/facebookresearch/esm.git
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 2.6 MB/s eta 0:00:00
# ...
# Cloning into 'esm'...
# remote: Enumerating objects: 1511, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 1511 (delta 46), reused 101 (delta 36), pack-reused 1360
# Receiving objects: 100% (1511/1511), 11.78 MiB | 8.86 MiB/s, done.
# Resolving deltas: 100% (895/895), done.
# Updating files: 100% (476/476), done.

# %%
import shutil
shutil.copy('../../MUTarget_data/combined_columns.csv', 'data/combined_columns.csv')
# Out:
# 'data/combined_columns.csv'
