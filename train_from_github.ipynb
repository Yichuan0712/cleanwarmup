# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Yichuan0712/CLEAN.git
# Out:
# Cloning into 'CLEAN'...
# remote: Enumerating objects: 5711, done.
# remote: Counting objects: 100% (5527/5527), done.
# remote: Compressing objects: 100% (5425/5425), done.
# remote: Total 5711 (delta 145), reused 5446 (delta 101), pack-reused 184
# Receiving objects: 100% (5711/5711), 133.12 MiB | 15.44 MiB/s, done.
# Resolving deltas: 100% (207/207), done.

# %%
import os
os.chdir('/content/CLEAN/app')
current_path = os.getcwd()
os.listdir(current_path)
# Out:
# ['train-supconH.py',
#  'results',
#  'data',
#  'build.py',
#  'DEMO.ipynb',
#  'requirements.txt',
#  'src',
#  'inference.py',
#  'train-triplet.py',
#  'CLEAN_infer_fasta.py',
#  'gmm.py']

# %%
# !pip install fair-esm  # latest release
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 1.3 MB/s eta 0:00:00
# ...

# %%
from src.CLEAN.utils import compute_esm_distance
train_file_list = ['train_01', 'train_12', 'train_23', 'train_34', 'train_40']
for train_file in train_file_list:
  compute_esm_distance(train_file)
train_file_list = ['nodual_train_01', 'nodual_train_12', 'nodual_train_23', 'nodual_train_34', 'nodual_train_40']
for train_file in train_file_list:
  compute_esm_distance(train_file)
# Out:
# 100%|██████████| 9/9 [00:00<00:00, 4882.14it/s]
# Calculating distance map, number of unique EC is 9
# 9it [00:00, 6005.21it/s]
# 100%|██████████| 9/9 [00:00<00:00, 3709.58it/s]
# Calculating distance map, number of unique EC is 9
# 9it [00:00, 3931.34it/s]
# 100%|██████████| 9/9 [00:00<00:00, 5858.88it/s]
# Calculating distance map, number of unique EC is 9
# 9it [00:00, 3186.62it/s]
# 100%|██████████| 9/9 [00:00<00:00, 5005.14it/s]
# Calculating distance map, number of unique EC is 9
# 9it [00:00, 2930.80it/s]
# 100%|██████████| 9/9 [00:00<00:00, 7177.93it/s]
# Calculating distance map, number of unique EC is 9
# 9it [00:00, 5260.41it/s]
# 100%|██████████| 8/8 [00:00<00:00, 6526.83it/s]
# Calculating distance map, number of unique EC is 8
# 8it [00:00, 4601.54it/s]
# 100%|██████████| 8/8 [00:00<00:00, 3465.29it/s]
# Calculating distance map, number of unique EC is 8
# 8it [00:00, 4803.10it/s]
# 100%|██████████| 8/8 [00:00<00:00, 7191.26it/s]
# ...

# %%
# !python train-triplet.py --training_data train_01 --model_name triplet01 --epoch 2500
# !python train-triplet.py --training_data train_12 --model_name triplet12 --epoch 2500
# !python train-triplet.py --training_data train_23 --model_name triplet23 --epoch 2500
# !python train-triplet.py --training_data train_34 --model_name triplet34 --epoch 2500
# !python train-triplet.py --training_data train_40 --model_name triplet40 --epoch 2500
# Out:
# Streaming output truncated to the last 5000 lines.
# ---------------------------------------------------------------------------
# | end of epoch 853 | time:  0.01s | training loss 0.0460
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 854 | time:  0.01s | training loss 0.2276
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 855 | time:  0.01s | training loss 0.1789
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 856 | time:  0.01s | training loss 0.2584
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# ...

# %%
# !python train-supconH.py --training_data train_01 --model_name supcon01 --epoch 1500 --n_pos 9 --n_neg 30 -T 0.1
# !python train-supconH.py --training_data train_12 --model_name supcon12 --epoch 1500 --n_pos 9 --n_neg 30 -T 0.1
# !python train-supconH.py --training_data train_23 --model_name supcon23 --epoch 1500 --n_pos 9 --n_neg 30 -T 0.1
# !python train-supconH.py --training_data train_34 --model_name supcon34 --epoch 1500 --n_pos 9 --n_neg 30 -T 0.1
# !python train-supconH.py --training_data train_40 --model_name supcon40 --epoch 1500 --n_pos 9 --n_neg 30 -T 0.1
# Out:
# Streaming output truncated to the last 5000 lines.
# ---------------------------------------------------------------------------
# | end of epoch 1365 | time:  0.08s | training loss 2.3274
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 1366 | time:  0.08s | training loss 2.2679
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 1367 | time:  0.08s | training loss 2.3644
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 1368 | time:  0.08s | training loss 2.3368
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# ...
