# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Yichuan0712/CLEAN.git
# Out:
# Cloning into 'CLEAN'...
# remote: Enumerating objects: 15898, done.
# remote: Counting objects: 100% (10585/10585), done.
# remote: Compressing objects: 100% (10351/10351), done.
# remote: Total 15898 (delta 258), reused 10524 (delta 224), pack-reused 5313
# Receiving objects: 100% (15898/15898), 106.93 MiB | 11.23 MiB/s, done.
# Resolving deltas: 100% (260/260), done.
# Updating files: 100% (18400/18400), done.

# %%
import os
os.chdir('/content/CLEAN/app')
current_path = os.getcwd()
os.listdir(current_path)
# Out:
# ['inference.py',
#  'CLEAN_infer_fasta.py',
#  'train-triplet.py',
#  'build.py',
#  'results',
#  'train-supconH.py',
#  'src',
#  'requirements.txt',
#  'data',
#  'gmm.py']

# %%
# !pip install fair-esm # latest release
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 3.7 MB/s eta 0:00:00
# ...

# %%
from src.CLEAN.utils import compute_esm_distance
train_file_list = ['TargetP2_train_01', 'TargetP2_train_12', 'TargetP2_train_23', 'TargetP2_train_34', 'TargetP2_train_40']
for train_file in train_file_list:
  compute_esm_distance(train_file)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 111.45it/s]
# Calculating distance map, number of unique EC is 5
# 5it [00:00, 67.60it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1194.14it/s]
# Calculating distance map, number of unique EC is 5
# 5it [00:00, 6698.03it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1119.14it/s]
# Calculating distance map, number of unique EC is 5
# 5it [00:00, 5103.80it/s]
# 100%|██████████| 5/5 [00:00<00:00, 1134.39it/s]
# Calculating distance map, number of unique EC is 5
# 5it [00:00, 6219.31it/s]
# 100%|██████████| 5/5 [00:00<00:00, 2510.96it/s]
# Calculating distance map, number of unique EC is 5
# 5it [00:00, 3580.59it/s]

# %%
# !python train-triplet.py --training_data TargetP2_train_01 --model_name TargetP2_triplet_01 --epoch 2500
# !python train-triplet.py --training_data TargetP2_train_12 --model_name TargetP2_triplet_12 --epoch 2500
# !python train-triplet.py --training_data TargetP2_train_23 --model_name TargetP2_triplet_23 --epoch 2500
# !python train-triplet.py --training_data TargetP2_train_34 --model_name TargetP2_triplet_34 --epoch 2500
# !python train-triplet.py --training_data TargetP2_train_40 --model_name TargetP2_triplet_40 --epoch 2500

# %%
with open('/content/CLEAN/app/data/model/TargetP2supcon01p9n30_2000.pth', 'w') as file: pass
# !python train-supconH.py --training_data TargetP2_train_01 --model_name TargetP2supcon01p9n30 --epoch 2000 --n_pos 9 --n_neg 30 -T 0.1
# !python train-supconH.py --training_data TargetP2_train_12 --model_name TargetP2_supcon_12_9p30n --epoch 2000 --n_pos 9 --n_neg 30 -T 0.1
# !python train-supconH.py --training_data TargetP2_train_23 --model_name TargetP2_supcon_23_9p30n --epoch 2000 --n_pos 9 --n_neg 30 -T 0.1
# !python train-supconH.py --training_data TargetP2_train_34 --model_name TargetP2_supcon_34_9p30n --epoch 2000 --n_pos 9 --n_neg 30 -T 0.1
# !python train-supconH.py --training_data TargetP2_train_40 --model_name TargetP2_supcon_40_9p30n --epoch 2000 --n_pos 9 --n_neg 30 -T 0.1
# Out:
# Streaming output truncated to the last 5000 lines.
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 364 | time:  0.05s | training loss 2.4598
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 365 | time:  0.05s | training loss 3.0274
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 366 | time:  0.04s | training loss 2.4214
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 367 | time:  0.05s | training loss 2.3829
# ---------------------------------------------------------------------------
# ...

# %%
with open('/content/CLEAN/app/data/model/TargetP2supcon12p9n30_2000.pth', 'w') as file: pass
# !python train-supconH.py --training_data TargetP2_train_12 --model_name TargetP2supcon12p9n30 --epoch 2000 --n_pos 9 --n_neg 30 -T 0.1
# Out:
# Streaming output truncated to the last 5000 lines.
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 363 | time:  0.05s | training loss 2.4541
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 364 | time:  0.04s | training loss 2.7391
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 365 | time:  0.04s | training loss 2.6282
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 366 | time:  0.04s | training loss 2.6966
# ---------------------------------------------------------------------------
# ...

# %%
with open('/content/CLEAN/app/data/model/TargetP2supcon23p9n30_2000.pth', 'w') as file: pass
# !python train-supconH.py --training_data TargetP2_train_23 --model_name TargetP2supcon23p9n30 --epoch 2000 --n_pos 9 --n_neg 30 -T 0.1
# Out:
# Streaming output truncated to the last 5000 lines.
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 363 | time:  0.04s | training loss 2.4470
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 364 | time:  0.05s | training loss 2.6404
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 365 | time:  0.04s | training loss 2.4910
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 366 | time:  0.05s | training loss 2.7629
# ---------------------------------------------------------------------------
# ...

# %%
with open('/content/CLEAN/app/data/model/TargetP2supcon34p9n30_2000.pth', 'w') as file: pass
# !python train-supconH.py --training_data TargetP2_train_34 --model_name TargetP2supcon34p9n30 --epoch 2000 --n_pos 9 --n_neg 30 -T 0.1
# Out:
# Streaming output truncated to the last 5000 lines.
# ---------------------------------------------------------------------------
# | end of epoch 363 | time:  0.04s | training loss 2.3802
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 364 | time:  0.05s | training loss 2.6123
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 365 | time:  0.04s | training loss 3.4242
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 366 | time:  0.05s | training loss 2.3974
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# ...

# %%
with open('/content/CLEAN/app/data/model/TargetP2supcon40p9n30_2000.pth', 'w') as file: pass
# !python train-supconH.py --training_data TargetP2_train_40 --model_name TargetP2supcon40p9n30 --epoch 2000 --n_pos 9 --n_neg 30 -T 0.1
# Out:
# Streaming output truncated to the last 5000 lines.
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 365 | time:  0.04s | training loss 2.3874
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 366 | time:  0.05s | training loss 2.5210
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 367 | time:  0.05s | training loss 2.4513
# ---------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# | end of epoch 368 | time:  0.04s | training loss 2.4869
# ---------------------------------------------------------------------------
# ...
