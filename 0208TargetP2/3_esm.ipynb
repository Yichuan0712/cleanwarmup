# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive')
current_path = os.getcwd()
os.listdir(current_path)
# Out:
# ['Colab Notebooks', 'MUTarget_data', 'TargetP2_data']

# %%
# !git clone https://github.com/Yichuan0712/CLEAN.git
# Out:
# Cloning into 'CLEAN'...
# remote: Enumerating objects: 6299, done.
# remote: Counting objects: 100% (986/986), done.
# remote: Compressing objects: 100% (754/754), done.
# remote: Total 6299 (delta 252), reused 929 (delta 222), pack-reused 5313
# Receiving objects: 100% (6299/6299), 90.13 MiB | 9.65 MiB/s, done.
# Resolving deltas: 100% (254/254), done.
# Updating files: 100% (5395/5395), done.

# %%
import os
os.chdir('/content/drive/MyDrive/CLEAN/app')
current_path = os.getcwd()
os.listdir(current_path)
# Out:
# ['CLEAN_infer_fasta.py',
#  'build.py',
#  'data',
#  'gmm.py',
#  'inference.py',
#  'requirements.txt',
#  'results',
#  'src',
#  'train-supconH.py',
#  'train-triplet.py']

# %%
# import shutil

# # 替换以下路径为你想删除的文件夹路径
# folder_path = '/content/CLEAN/app/data/model'

# # 删除非空文件夹
# shutil.rmtree(folder_path)

# %%
# import shutil

# # 替换以下路径为你想删除的文件夹路径
# folder_path = '/content/CLEAN/app/data/esm_data'

# # 删除非空文件夹
# shutil.rmtree(folder_path)

# %%
# import os
# os.chdir('/content/CLEAN/app')
# current_path = os.getcwd()
# os.listdir(current_path)

# %%
# !pip install fair-esm  # latest release
# !git clone https://github.com/facebookresearch/esm.git
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 2.7 MB/s eta 0:00:00
# ...
# Cloning into 'esm'...
# remote: Enumerating objects: 1511, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 1511 (delta 46), reused 102 (delta 36), pack-reused 1360
# Receiving objects: 100% (1511/1511), 11.26 MiB | 10.39 MiB/s, done.
# Resolving deltas: 100% (900/900), done.
# Updating files: 100% (476/476), done.

# %%
from src.CLEAN.utils import csv_to_fasta, mutate_single_seq_ECs, retrive_esm1b_embedding, compute_esm_distance
csv_to_fasta("data/TargetP2.csv", "data/TargetP2.fasta")

# %%
# !python esm/scripts/extract.py esm2_t6_8M_UR50D data/TargetP2.fasta data/esm_data --include mean
# Out:
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/models/esm2_t6_8M_UR50D.pt" to /root/.cache/torch/hub/checkpoints/esm2_t6_8M_UR50D.pt
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/regression/esm2_t6_8M_UR50D-contact-regression.pt" to /root/.cache/torch/hub/checkpoints/esm2_t6_8M_UR50D-contact-regression.pt
# Transferred model to GPU
# Read data/TargetP2.fasta with 13005 sequences
# Processing 1 of 1956 batches (67 sequences)
# Processing 2 of 1956 batches (60 sequences)
# Processing 3 of 1956 batches (54 sequences)
# Processing 4 of 1956 batches (51 sequences)
# Processing 5 of 1956 batches (49 sequences)
# Processing 6 of 1956 batches (48 sequences)
# Processing 7 of 1956 batches (47 sequences)
# Processing 8 of 1956 batches (46 sequences)
# Processing 9 of 1956 batches (45 sequences)
# Processing 10 of 1956 batches (44 sequences)
# Processing 11 of 1956 batches (42 sequences)
# Processing 12 of 1956 batches (41 sequences)
# ...

# %%
# !cp -r /content/CLEAN/app/data/esm_data /content/drive/MyDrive/esm_TargetP2

# %%
# 压缩名为folder_name的文件夹到archive_name.zip
# !zip -r /content/drive/MyDrive/esm_data.zip /content/drive/MyDrive/esm_data
import shutil
shutil.make_archive('/content/drive/MyDrive/CLEAN/app/data/test', 'zip', '/content/drive/MyDrive/CLEAN/app/data/esm_data')
# Out:
# '/content/drive/MyDrive/CLEAN/app/data/test.zip'

# %% [markdown]
# https://stackoverflow.com/questions/54660967/google-colab-having-problems-with-drive-folders-containing-lots-of-files

# %% [markdown]
# Shit happens when you have too many files to move to Google Drive
