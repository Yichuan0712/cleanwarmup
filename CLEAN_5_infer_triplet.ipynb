# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/CLEAN/app')
current_path = os.getcwd()
os.listdir(current_path)
# Out:
# ['CLEAN_infer_fasta.py',
#  'DEMO.ipynb',
#  'build.py',
#  'data',
#  'gmm.py',
#  'inference.py',
#  'requirements.txt',
#  'results',
#  'src',
#  'train-supconH.py',
#  'train-triplet.py',
#  'esm',
#  'new-train-triplet.py',
#  'new-train-supconH.py']

# %%
# !pip install fair-esm  # latest release
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 2.6 MB/s eta 0:00:00
# ...

# %%
from src.CLEAN.utils import csv_to_fasta, retrive_esm1b_embedding
csv_to_fasta("data/new.csv", "data/new.fasta")
retrive_esm1b_embedding("new")

# %%
from src.CLEAN.infer import infer_pvalue
train_data = "combined_columns"
test_data = "new"
infer_pvalue(train_data, test_data, p_value=1e-1, nk_random=1, report_metrics=True, pretrained=False, model_name='combined_columns_triplet')
# Out:
# The embedding sizes for train and test: torch.Size([5398, 128]) torch.Size([6, 128])
# 100%|██████████| 9/9 [00:00<00:00, 3949.03it/s]
# Calculating eval distance map, between 6 test ids and 9 train EC cluster centers
# 6it [00:00, 4489.09it/s]
# 100%|██████████| 9/9 [00:00<00:00, 5516.40it/s]
# 1000it [00:00, 9461.87it/s]
# 100%|██████████| 6/6 [00:00<00:00, 675.19it/s]
# ############ EC calling results using random chosen 1k samples ############
# ---------------------------------------------------------------------------
# >>> total samples: 6 | total ec: 5
# >>> precision: 0.833 | recall: 0.833| F1: 0.833 | AUC: 0.917
# ---------------------------------------------------------------------------

# %%
from src.CLEAN.infer import infer_maxsep
train_data = "combined_columns"
test_data = "new"
infer_maxsep(train_data, test_data, report_metrics=True, pretrained=False, model_name="combined_columns_triplet")
# Out:
# The embedding sizes for train and test: torch.Size([5398, 128]) torch.Size([6, 128])
# 100%|██████████| 9/9 [00:00<00:00, 1048.34it/s]
# Calculating eval distance map, between 6 test ids and 9 train EC cluster centers
# 6it [00:00, 88.98it/s]
# ############ EC calling results using maximum separation ############
# ---------------------------------------------------------------------------
# >>> total samples: 6 | total ec: 5
# >>> precision: 0.75 | recall: 0.833| F1: 0.778 | AUC: 0.9
# ---------------------------------------------------------------------------
