# %% [markdown]
# ONLY RUN THIS ONCE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/CLEAN/app')
current_path = os.getcwd()
os.listdir(current_path)
# Out:
# ['CLEAN_infer_fasta.py',
#  'DEMO.ipynb',
#  'build.py',
#  'data',
#  'gmm.py',
#  'inference.py',
#  'requirements.txt',
#  'results',
#  'src',
#  'train-supconH.py',
#  'train-triplet.py',
#  'new-train-triplet.py',
#  'new-train-supconH.py',
#  'esm']

# %%
# !pip install fair-esm  # latest release
# Out:
# Collecting fair-esm
#   Downloading fair_esm-2.0.0-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: fair-esm
# Successfully installed fair-esm-2.0.0

# %%
from src.CLEAN.utils import csv_to_fasta, mutate_single_seq_ECs, retrive_esm1b_embedding, compute_esm_distance
csv_to_fasta("data/combined_columns.csv", "data/combined_columns.fasta")

# %%
# !python esm/scripts/extract.py esm2_t6_8M_UR50D data/combined_columns.fasta data/esm_data --include mean

# %%
from src.CLEAN.newutilsT6 import compute_esm_distance
train_file = "combined_columns"
compute_esm_distance(train_file)

train_file_list = ['train_01', 'train_12', 'train_23', 'train_34', 'train_40']
for train_file in train_file_list:
  compute_esm_distance(train_file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-997bec4d8588> in <cell line: 3>()
#       1 from src.CLEAN.newutilsT6 import compute_esm_distance
#       2 train_file = "combined_columns"
# ----> 3 compute_esm_distance(train_file)
#       4
#       5 train_file_list = ['train_01', 'train_12', 'train_23', 'train_34', 'train_40']
#
# /content/drive/MyDrive/CLEAN/app/src/CLEAN/newutilsT6.py in compute_esm_distance(train_file)
#     129     device = torch.device("cuda:0" if use_cuda else "cpu")
#     130     dtype = torch.float32
# --> 131     esm_emb = esm_embedding(ec_id_dict, device, dtype)
#     132     esm_dist = get_dist_map(ec_id_dict, esm_emb, device, dtype)
#     133     pickle.dump(esm_dist, open('./data/distance_map/' + train_file + '.pkl', 'wb'))
#
# /content/drive/MyDrive/CLEAN/app/src/CLEAN/newutilsT6.py in esm_embedding(ec_id_dict, device, dtype)
#      75     for ec in list(ec_id_dict.keys()):
#      76         ids_for_query = list(ec_id_dict[ec])
# ---> 77         esm_to_cat = [load_esm(id) for id in ids_for_query]
#      78         esm_emb = esm_emb + esm_to_cat
#      79     return torch.cat(esm_emb).to(device=device, dtype=dtype)
#
# /content/drive/MyDrive/CLEAN/app/src/CLEAN/newutilsT6.py in <listcomp>(.0)
#      75     for ec in list(ec_id_dict.keys()):
#      76         ids_for_query = list(ec_id_dict[ec])
# ---> 77         esm_to_cat = [load_esm(id) for id in ids_for_query]
#      78         esm_emb = esm_emb + esm_to_cat
#      79     return torch.cat(esm_emb).to(device=device, dtype=dtype)
#
# /content/drive/MyDrive/CLEAN/app/src/CLEAN/newutilsT6.py in load_esm(lookup)
#      62
#      63 def load_esm(lookup):
# ---> 64     esm = format_esm(torch.load('./data/esm_data/' + lookup + '.pt'))
#      65     return esm.unsqueeze(0)
#      66
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     985
#     986     with _open_file_like(f, 'rb') as opened_file:
# --> 987         if _is_zipfile(opened_file):
#     988             # The zipfile reader is going to advance the current file position.
#     989             # If we want to actually tail call to torch.jit.load, we need to
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _is_zipfile(f)
#     119     start = f.tell()
#     120
# --> 121     byte = f.read(1)
#     122     while byte != b"":
#     123         read_bytes.append(byte)
#
# KeyboardInterrupt:
